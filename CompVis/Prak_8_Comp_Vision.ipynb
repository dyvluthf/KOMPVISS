# %%
# ==========================================
# PRAKTIKUM YOLOv5 - DETEKSI OBJEK
# ==========================================

# 1. Clone Repository YOLOv5
# !git clone https://github.com/ultralytics/yolov5

# 2. Masuk ke folder YOLOv5
# %cd yolov5

# 3. Install requirements
# !pip install -r requirements.txt

# ==========================================
# 4. Import Library
# ==========================================
import cv2
import matplotlib.pyplot as plt
from google.colab import files
from IPython.display import Image, display

# ==========================================
# 5. Upload gambar sendiri
# ==========================================
uploaded = files.upload()

# Ambil nama file otomatis
file_name = list(uploaded.keys())[0]

print("File yang diupload:", file_name)

# ==========================================
# 6. Jalankan YOLOv5 Detection
# ==========================================
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source "{file_name}"

# ==========================================
# 7. Menampilkan hasil deteksi
# ==========================================
import glob

# Cari hasil gambar deteksi
result_img = glob.glob('/content/yolov5/runs/detect/exp/*')[0]

# Tampilkan hasil
display(Image(filename=result_img))

# ==========================================
# 8. Shape dan Dtype Citra
# ==========================================
img = cv2.imread(result_img)

print("Shape Citra :", img.shape)
print("Dtype Citra :", img.dtype)

# ==========================================
# 9. Menampilkan citra menggunakan matplotlib
# ==========================================
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,8))
plt.imshow(img_rgb)
plt.title("Hasil Deteksi YOLOv5")
plt.axis("off")
plt.show()
# Out:
# c:\Users\dyvan\Downloads\CompVis\yolov5
# fatal: destination path 'yolov5' already exists and is not an empty directory.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\dyvan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Defaulting to user installation because normal site-packages is not writeable
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 17
#      13
#      14 # ==========================================
#      15 # 4. Import Library
#      16 # ==========================================
# ---> 17 import cv2
#      18 import matplotlib.pyplot as plt
#      19 from google.colab import files
# ...
